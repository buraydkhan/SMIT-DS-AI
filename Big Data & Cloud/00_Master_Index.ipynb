# %% [markdown]
# # ⚡ Big Data, Apache Spark & Cloud Crash Course: Master Index
#
# Welcome to the **Big Data, Apache Spark, and Cloud (AWS/Azure) Crash Course**!
#
# ---
#
# ## 📌 Course Syllabus & Navigation
#
# | Topic | Notebook Title | Key Concepts Covered |
# | :--- | :--- | :--- |
# | **01** | [`topic_01_big_data_fundamentals_and_distributed_systems.ipynb`](./topic_01_big_data_fundamentals_and_distributed_systems.ipynb) | 5 V's, HDFS, CAP Theorem, MapReduce Python Simulation |
# | **02** | [`topic_02_apache_spark_architecture_and_rdds.ipynb`](./topic_02_apache_spark_architecture_and_rdds.ipynb) | Spark Drivers/Executors, RDDs, Lineage Graphs, PySpark Setup |
# | **03** | [`topic_03_pyspark_dataframes_and_transformations.ipynb`](./topic_03_pyspark_dataframes_and_transformations.ipynb) | Lazy Evaluation, Narrow vs Wide Dependencies, DataFrames & Structs |
# | **04** | [`topic_04_data_wrangling_udfs_and_window_functions.ipynb`](./topic_04_data_wrangling_udfs_and_window_functions.ipynb) | Window Functions (`lead`/`lag`), Pandas UDFs, Handling Missing Data |
# | **05** | [`topic_05_spark_optimization_shuffling_and_joins.ipynb`](./topic_05_spark_optimization_shuffling_and_joins.ipynb) | Broadcast Joins, Shuffling, Key Salting for Data Skew, AQE & Caching |
# | **06** | [`topic_06_structured_streaming_and_realtime_processing.ipynb`](./topic_06_structured_streaming_and_realtime_processing.ipynb) | Micro-batching, Watermarks, Event-Time Processing, Output Modes |
# | **07** | [`topic_07_cloud_data_lakes_and_delta_lake.ipynb`](./topic_07_cloud_data_lakes_and_delta_lake.ipynb) | AWS S3 / ADLS, Parquet Partitioning, Delta Lake ACID & Time-Travel |
# | **08** | [`topic_08_cloud_managed_spark_aws_and_azure.ipynb`](./topic_08_cloud_managed_spark_aws_and_azure.ipynb) | AWS EMR, AWS Glue, Databricks, IAM Security & `boto3` Cloud Ops |
# | **09** | [`topic_09_cloud_pipeline_orchestration_and_ci_cd.ipynb`](./topic_09_cloud_pipeline_orchestration_and_ci_cd.ipynb) | Airflow DAGs, PyTest for PySpark DataFrames, CI/CD Packaging |
# | **10** | [`topic_10_capstone_end_to_end_big_data_cloud_etl.ipynb`](./topic_10_capstone_end_to_end_big_data_cloud_etl.ipynb) | **Capstone Project:** Complete Distributed Cloud ETL Pipeline |
#
# ---
#
# ## 🛠️ Environment Verification Setup
#
# Run the code cell below to check Python & PySpark system imports.

# %%
import sys

print("=== Big Data & PySpark Environment Check ===")
print(f"Python Version: {sys.version.split()[0]}")

try:
    import pyspark
    print(f"PySpark Version: {pyspark.__version__}")
except ImportError:
    print("⚠️ PySpark package not installed. Installing via pip: 'pip install pyspark pandas pyarrow boto3'")

try:
    import pandas as pd
    import pyarrow as pa
    import boto3
    print(f"Pandas Version:  {pd.__version__}")
    print(f"PyArrow Version: {pa.__version__}")
    print(f"Boto3 Version:   {boto3.__version__}")
except ImportError as e:
    print(f"Info: {e}")

print("\n✅ Core dependencies loaded successfully!")
