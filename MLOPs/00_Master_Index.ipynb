# %% [markdown]
# # 🚀 MLOps Crash Course: Master Index & Roadmap
#
# Welcome to the **MLOps Crash Course**! This course bridges the gap between Machine Learning engineering and DevOps production practices.
#
# ---
#
# ## 📌 Course Syllabus & Navigation
#
# | Topic | Notebook Title | Key Concepts Covered |
# | :--- | :--- | :--- |
# | **01** | [`topic_01_introduction_to_mlops.ipynb`](./topic_01_introduction_to_mlops.ipynb) | MLOps Lifecycle, Technical Debt, Google Maturity Levels (0, 1, 2) |
# | **02** | [`topic_02_data_and_model_versioning.ipynb`](./topic_02_data_and_model_versioning.ipynb) | DVC Concepts, Content-Addressable Storage, Data Lineage & Hashing |
# | **03** | [`topic_03_experiment_tracking_and_model_registry.ipynb`](./topic_03_experiment_tracking_and_model_registry.ipynb) | MLflow Tracking, Params/Metrics/Artifacts, Model Registry Lifecycle |
# | **04** | [`topic_04_ml_pipeline_orchestration.ipynb`](./topic_04_ml_pipeline_orchestration.ipynb) | Modular DAGs, Task Dependencies, Quality Gatekeeping, Prefect/Airflow |
# | **05** | [`topic_05_model_packaging_and_docker_apis.ipynb`](./topic_05_model_packaging_and_docker_apis.ipynb) | Dockerization, FastAPI Microservices, Pydantic Schema Validation |
# | **06** | [`topic_06_ci_cd_for_machine_learning.ipynb`](./topic_06_ci_cd_for_machine_learning.ipynb) | PyTest, Data Validation, Invariance Tests, GitHub Actions Automation |
# | **07** | [`topic_07_model_deployment_strategies.ipynb`](./topic_07_model_deployment_strategies.ipynb) | Blue-Green, Canary Routing, Shadow Deployments & Traffic Splitting |
# | **08** | [`topic_08_model_monitoring_and_drift_detection.ipynb`](./topic_08_model_monitoring_and_drift_detection.ipynb) | Data Drift (KS-Test, PSI), Concept Drift & Automated Retraining Signals |
# | **09** | [`topic_09_feature_stores_and_governance.ipynb`](./topic_09_feature_stores_and_governance.ipynb) | Training-Serving Skew, Offline/Online Stores, Point-in-time Joins |
# | **10** | [`topic_10_capstone_end_to_end_mlops_project.ipynb`](./topic_10_capstone_end_to_end_mlops_project.ipynb) | **Capstone Project:** Complete Unified Production MLOps Workflow |
#
# ---
#
# ## 🛠️ Environment Prerequisites & Package Setup
#
# Run the cell below to verify your Python environment dependencies.

# %%
import sys
import numpy as np
import pandas as pd
import sklearn
import mlflow
import scipy
import fastapi
import uvicorn

print("=== MLOps Environment Check ===")
print(f"Python Version:  {sys.version.split()[0]}")
print(f"NumPy Version:   {np.__version__}")
print(f"Pandas Version:  {pd.__version__}")
print(f"Scikit-Learn:    {sklearn.__version__}")
print(f"MLflow Version:  {mlflow.__version__}")
print(f"SciPy Version:   {scipy.__version__}")
print(f"FastAPI Version: {fastapi.__version__}")
print("\n✅ All core libraries imported successfully!")
