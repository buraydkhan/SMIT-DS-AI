# %% [markdown]
# # 🚀 Topic 20: K-Nearest Neighbors - Effect of K
#
# [⬅️ Previous Topic](topic_19_knn_intuition.ipynb) | [🏠 Master Index](00_Master_Index.ipynb) | [Next Topic ➡️](topic_21_svm_maximum_margin.ipynb)
# ---

# %% [markdown]
# ### Topic 20: K-Nearest Neighbors - Effect of K
# Comparing small $K$ (noisy, overfits) vs large $K$ (smoother boundary).

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.datasets import make_classification

X_clf, y_clf = make_classification(n_samples=100, n_features=2, n_redundant=0, random_state=42)

for k in [1, 5, 25]:
    clf = KNeighborsClassifier(n_neighbors=k).fit(X_clf, y_clf)
    print(f"K={k:2d} -> Accuracy: {clf.score(X_clf, y_clf):.2%}")

# %% [markdown]
# ---
#
# [⬅️ Previous Topic](topic_19_knn_intuition.ipynb) | [🏠 Master Index](00_Master_Index.ipynb) | [Next Topic ➡️](topic_21_svm_maximum_margin.ipynb)
