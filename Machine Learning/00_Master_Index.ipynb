# %% [markdown]
# # 📚 Machine Learning Crash Course: 40 Master Topic Index
#
# Welcome to the **40-Topic Machine Learning Crash Course**! Click on any topic below to open its dedicated Jupyter Notebook.
#
# ---

# %% [markdown]
# - [Topic 01: What is Machine Learning?](topic_01_what_is_machine_learning.ipynb)
# - [Topic 02: Vectors & Matrices in Machine Learning](topic_02_vectors_and_matrices.ipynb)
# - [Topic 03: Cost Functions & Gradient Descent Intuition](topic_03_cost_functions_and_gradient_descent.ipynb)
# - [Topic 04: Gradient Descent Code Example](topic_04_gradient_descent_code.ipynb)
# - [Topic 05: Loading & Exploring Data (EDA)](topic_05_loading_and_exploring_data.ipynb)
# - [Topic 06: Handling Missing Values](topic_06_handling_missing_values.ipynb)
# - [Topic 07: Feature Scaling (Standardization)](topic_07_feature_scaling.ipynb)
# - [Topic 08: Categorical Encoding (One-Hot Encoding)](topic_08_categorical_encoding.ipynb)
# - [Topic 09: Train-Test Split (Preventing Data Leakage)](topic_09_train_test_split.ipynb)
# - [Topic 10: Simple Linear Regression](topic_10_simple_linear_regression.ipynb)
# - [Topic 11: Multiple Linear Regression](topic_11_multiple_linear_regression.ipynb)
# - [Topic 12: Regression Evaluation Metrics](topic_12_regression_evaluation_metrics.ipynb)
# - [Topic 13: Underfitting vs. Overfitting](topic_13_underfitting_vs_overfitting.ipynb)
# - [Topic 14: Ridge Regularization (L2 Penalty)](topic_14_ridge_regularization.ipynb)
# - [Topic 15: Lasso Regularization (L1 Penalty & Feature Selection)](topic_15_lasso_regularization.ipynb)
# - [Topic 16: What is Classification?](topic_16_what_is_classification.ipynb)
# - [Topic 17: Logistic Regression & Sigmoid Function](topic_17_logistic_regression_sigmoid.ipynb)
# - [Topic 18: Logistic Regression Code Example](topic_18_logistic_regression_code.ipynb)
# - [Topic 19: K-Nearest Neighbors (KNN) Intuition](topic_19_knn_intuition.ipynb)
# - [Topic 20: K-Nearest Neighbors - Effect of K](topic_20_knn_effect_of_k.ipynb)
# - [Topic 21: Support Vector Machines (SVM) - Maximum Margin](topic_21_svm_maximum_margin.ipynb)
# - [Topic 22: SVM Kernel Trick Intuition](topic_22_svm_kernel_trick.ipynb)
# - [Topic 23: SVM Code & Boundary Plotting](topic_23_svm_code_and_plotting.ipynb)
# - [Topic 24: Decision Trees Intuition](topic_24_decision_trees_intuition.ipynb)
# - [Topic 25: Visualizing the Decision Tree](topic_25_visualizing_decision_tree.ipynb)
# - [Topic 26: Random Forests & Bagging Ensemble Intuition](topic_26_random_forests_bagging.ipynb)
# - [Topic 27: Random Forest Feature Importances](topic_27_random_forest_feature_importance.ipynb)
# - [Topic 28: Gradient Boosting Intuition](topic_28_gradient_boosting_intuition.ipynb)
# - [Topic 29: Gradient Boosting Code Example](topic_29_gradient_boosting_code.ipynb)
# - [Topic 30: Confusion Matrix & Accuracy](topic_30_confusion_matrix_and_accuracy.ipynb)
# - [Topic 31: Precision, Recall & F1-Score Intuition](topic_31_precision_recall_f1.ipynb)
# - [Topic 32: ROC Curve & AUC Score Intuition](topic_32_roc_curve_and_auc.ipynb)
# - [Topic 33: Classification Metrics Code & Visual Plots](topic_33_classification_metrics_plots.ipynb)
# - [Topic 34: K-Means Clustering Intuition & Code](topic_34_kmeans_clustering.ipynb)
# - [Topic 35: Finding Optimal K (Elbow Method)](topic_35_elbow_method_kmeans.ipynb)
# - [Topic 36: Principal Component Analysis (PCA)](topic_36_principal_component_analysis.ipynb)
# - [Topic 37: Scikit-Learn Pipelines](topic_37_scikit_learn_pipelines.ipynb)
# - [Topic 38: Hyperparameter Tuning (GridSearchCV)](topic_38_hyperparameter_tuning_gridsearch.ipynb)
# - [Topic 39: Intro to Neural Networks & Perceptrons](topic_39_intro_to_neural_networks.ipynb)
# - [Topic 40: Multi-Layer Perceptron (MLP) Loss Curve](topic_40_mlp_loss_curve.ipynb)
