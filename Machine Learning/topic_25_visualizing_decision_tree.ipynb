# %% [markdown]
# # 🚀 Topic 25: Visualizing the Decision Tree
#
# [⬅️ Previous Topic](topic_24_decision_trees_intuition.ipynb) | [🏠 Master Index](00_Master_Index.ipynb) | [Next Topic ➡️](topic_26_random_forests_bagging.ipynb)
# ---

# %% [markdown]
# ### Topic 25: Visualizing the Decision Tree
# Plotting the full visual split diagram of the Decision Tree.

# %%
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.datasets import make_classification

X_clf, y_clf = make_classification(n_samples=100, n_features=2, n_redundant=0, random_state=42)
dt = DecisionTreeClassifier(max_depth=3, random_state=42).fit(X_clf, y_clf)

plt.figure(figsize=(10, 5))
plot_tree(dt, filled=True, feature_names=['Feature_1', 'Feature_2'], class_names=['Class_0', 'Class_1'])
plt.title('Visual Decision Tree Splitting Diagram')
plt.show()

# %% [markdown]
# ---
#
# [⬅️ Previous Topic](topic_24_decision_trees_intuition.ipynb) | [🏠 Master Index](00_Master_Index.ipynb) | [Next Topic ➡️](topic_26_random_forests_bagging.ipynb)
