# %% [markdown]
# # 🚀 Topic 18: Logistic Regression Code Example
#
# [⬅️ Previous Topic](topic_17_logistic_regression_sigmoid.ipynb) | [🏠 Master Index](00_Master_Index.ipynb) | [Next Topic ➡️](topic_19_knn_intuition.ipynb)
# ---

# %% [markdown]
# ### Topic 18: Logistic Regression Code Example
# Fitting `LogisticRegression` on synthetic dataset.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import make_classification

X_clf, y_clf = make_classification(n_samples=100, n_features=2, n_redundant=0, random_state=42)

log_reg = LogisticRegression()
log_reg.fit(X_clf, y_clf)
print(f"Classification Accuracy: {log_reg.score(X_clf, y_clf):.2%}")

# %% [markdown]
# ---
#
# [⬅️ Previous Topic](topic_17_logistic_regression_sigmoid.ipynb) | [🏠 Master Index](00_Master_Index.ipynb) | [Next Topic ➡️](topic_19_knn_intuition.ipynb)
