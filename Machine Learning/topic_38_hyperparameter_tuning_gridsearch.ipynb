# %% [markdown]
# # 🚀 Topic 38: Hyperparameter Tuning (GridSearchCV)
#
# [⬅️ Previous Topic](topic_37_scikit_learn_pipelines.ipynb) | [🏠 Master Index](00_Master_Index.ipynb) | [Next Topic ➡️](topic_39_intro_to_neural_networks.ipynb)
# ---

# %% [markdown]
# ### Topic 38: Hyperparameter Tuning (GridSearchCV)
# **Intuition**: Automatically tests different combinations of model settings to find the optimal configuration.

# %%
import numpy as np
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

X = np.random.randn(100, 2)
y = np.random.choice([0, 1], 100)

pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('clf', LogisticRegression())
])

param_grid = {'clf__C': [0.1, 1.0, 10.0]}
grid = GridSearchCV(pipe, param_grid, cv=3).fit(X, y)
print("Best Parameters:", grid.best_params_)

# %% [markdown]
# ---
#
# [⬅️ Previous Topic](topic_37_scikit_learn_pipelines.ipynb) | [🏠 Master Index](00_Master_Index.ipynb) | [Next Topic ➡️](topic_39_intro_to_neural_networks.ipynb)
