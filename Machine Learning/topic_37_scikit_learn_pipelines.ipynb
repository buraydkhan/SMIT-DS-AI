# %% [markdown]
# # 🚀 Topic 37: Scikit-Learn Pipelines
#
# [⬅️ Previous Topic](topic_36_principal_component_analysis.ipynb) | [🏠 Master Index](00_Master_Index.ipynb) | [Next Topic ➡️](topic_38_hyperparameter_tuning_gridsearch.ipynb)
# ---

# %% [markdown]
# ### Topic 37: Scikit-Learn Pipelines
# **Intuition**: Assembly line for ML! Chains preprocessing (Imputer + Scaler) and model fitting into a single unit.

# %%
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

X = np.random.randn(100, 2)
y = np.random.choice([0, 1], 100)

pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('clf', LogisticRegression())
])
pipe.fit(X, y)
print(f"Pipeline Score: {pipe.score(X, y):.2%}")

# %% [markdown]
# ---
#
# [⬅️ Previous Topic](topic_36_principal_component_analysis.ipynb) | [🏠 Master Index](00_Master_Index.ipynb) | [Next Topic ➡️](topic_38_hyperparameter_tuning_gridsearch.ipynb)
