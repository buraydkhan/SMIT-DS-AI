# %% [markdown]
# # 🚀 Topic 24: Decision Trees Intuition
#
# [⬅️ Previous Topic](topic_23_svm_code_and_plotting.ipynb) | [🏠 Master Index](00_Master_Index.ipynb) | [Next Topic ➡️](topic_25_visualizing_decision_tree.ipynb)
# ---

# %% [markdown]
# ### Topic 24: Decision Trees Intuition
# **Intuition**: Plays a game of 20 Questions (e.g., Is Income > $50k? -> Yes -> Is Age > 30?). Splits features to minimize Gini Impurity (impurity = 0 means pure class split).

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import make_classification

X_clf, y_clf = make_classification(n_samples=100, n_features=2, n_redundant=0, random_state=42)

dt = DecisionTreeClassifier(max_depth=3, random_state=42)
dt.fit(X_clf, y_clf)
print(f"Decision Tree Depth: {dt.get_depth()} | Accuracy: {dt.score(X_clf, y_clf):.2%}")

# %% [markdown]
# ---
#
# [⬅️ Previous Topic](topic_23_svm_code_and_plotting.ipynb) | [🏠 Master Index](00_Master_Index.ipynb) | [Next Topic ➡️](topic_25_visualizing_decision_tree.ipynb)
